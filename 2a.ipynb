# %% [markdown]
# # Neutral-Atom Quantum Twin of $\mathrm{TmMgGaO}_4$
# ## Phase 2 — Field response, three-sublattice order, and finite-size crossover
#
# ### Aim
# This notebook builds a self-contained, paper-inspired quantum twin of the frustrated triangular-lattice magnet $\mathrm{TmMgGaO}_4$ using Pasqal's neutral-atom Hamiltonian and the EmuMPS tensor-network emulator. We derive the mapping from the material parameters $(J_1,\Delta_x,\Delta_z)$ to the programmable Rydberg interaction, Rabi frequency, and detuning; construct the preparation pulse; simulate the field sweep; and extract experimentally accessible observables from sampled bitstrings.
#
# The complete $7\times7$ register of 49 atoms is evolved, including all interactions and boundary atoms. Measurements are analysed on the central $5\times5$ region, leaving one active outer buffer layer. This larger 25-site analysis region improves sampling statistics but has stronger boundary sensitivity than the paper's two-layer-buffer convention, so that difference is documented throughout.
#
# ### Main outputs
#
# 1. the quantum-twin magnetisation curve $M^z(\Delta_z/J_1)$;
# 2. the connected three-sublattice structure factor $S^{zz}(\mathbf q_{1/3},\Delta_z/J_1)$;
# 3. bootstrap intervals from finite EmuMPS measurement sampling and $\chi=50/100$ convergence checks;
# 4. an $N=49$ finite-time pseudo-critical crossover estimate from systematic varying-window cubic fits;
# 5. raw bitstring and mean-occupation lattice visualisations around the crossover region.
#
# The pulse follows the timing and endpoint information available in the supplementary material but is not claimed to be the unpublished experimental waveform. Likewise, the crossover estimate is not the thermodynamic critical point or the paper's $N=256$ result. Fresh cloud-job identifiers are stored separately so results from earlier Phase-2 notebooks are never mixed with this analysis.

# %% [markdown]
# ## 0. Imports and explicit configuration
#
# `SUBMIT_NEW_JOBS` is a safety switch. Keep it `False` while inspecting the notebook. Change it to `True` exactly once to submit the fresh jobs, wait for all batches to finish, then change it back to `False` before rerunning. Batch IDs are stored in `phase2_paper_pulse_batches.json`.

# %%
import json
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import yaml
import pulser
from pulser import Register, Sequence
from pulser.backend import BitStrings
from pulser.devices import MockDevice
from pulser.pulse import Pulse
from pulser.waveforms import ConstantWaveform, RampWaveform
from pulser_pasqal import PasqalCloud
from pasqal_cloud import SDK

L=7
N=L*L
SHOTS=1000
DT_NS=10
CHI_MAIN=50
CHI_CHECK=100
OMEGA_OVER_2PI_MHZ=2.0
TARGET_DX_OVER_J1=1.08
FIELDS=np.array([1.,2.,2.5,2.75,3.,3.25,3.5,3.625,3.75,3.875,4.,4.125,4.25,4.375,4.5,4.625,4.875,5.,5.125,5.25,5.375,5.5,5.625,5.875,6.,8.,10.])
CHECK_FIELDS=np.array([3.5,4.0,4.5,5.0])
CREDENTIALS_FILE='credentials.example.yaml'
BATCH_FILE=Path('phase2_paper_pulse_batches.json')
SUBMIT_NEW_JOBS=False
print('Pulser',pulser.__version__,'| fields',len(FIELDS))
# Out:
# Pulser 1.8.0 | fields 27

# %% [markdown]
# ## 1. Material Hamiltonian
#
# The thulium magnetic moments are represented as pseudospin-$1/2$ variables on a triangular lattice:
# $$\frac{H_{\rm mat}}{\hbar}=J_1\sum_{\langle i,j\rangle}\sigma_i^z\sigma_j^z+J_2\sum_{\langle\langle i,j\rangle\rangle}\sigma_i^z\sigma_j^z+\sum_i(\Delta_x\sigma_i^x-\Delta_z\sigma_i^z).$$
#
# - $J_1>0$: nearest neighbours prefer opposite $z$ spins. On triangles this cannot be satisfied on every bond, creating geometrical frustration.
# - $J_2/J_1\simeq0.05$: weaker next-neighbour interaction.
# - $\Delta_x/J_1\simeq1.08$: intrinsic transverse field, producing quantum superpositions and spin flips.
# - $\Delta_z/J_1$: longitudinal material field scanned on our horizontal axis. High field favours $\sigma^z=+1$ and polarises the material.

# %% [markdown]
# ## 2. From the material Hamiltonian to the Rydberg Hamiltonian
#
# Our objective is to reproduce the material spin Hamiltonian
#
# $$\frac{H_{\mathrm{mat}}}{\hbar}=\sum_{i<j}J_{ij}\sigma_i^z\sigma_j^z+\Delta_x\sum_i\sigma_i^x-\Delta_z\sum_i\sigma_i^z$$
#
# using the neutral-atom Hamiltonian programmed through Pulser:
#
# $$\frac{H_{\mathrm{QPU}}}{\hbar}=\sum_{i<j}u_{ij}n_i n_j+\frac{\Omega}{2}\sum_i\sigma_i^x-\delta\sum_i n_i.$$
#
# All quantities here are angular frequencies:
#
# $$u_{ij}=\frac{U_{ij}}{\hbar}.$$
#
# The controls and interactions have the following meanings:
#
# - $u_{ij}$: Rydberg interaction between atoms $i$ and $j$;
# - $\Omega$: Rabi frequency controlling coherent transitions between $|g\rangle$ and $|r\rangle$;
# - $\delta$: laser detuning controlling the energetic preference for Rydberg excitation;
# - $n_i$: Rydberg occupation of atom $i$.
#
# The two atomic states are represented as
#
# $$n_i=0\quad\text{for }|g\rangle,\qquad n_i=1\quad\text{for }|r\rangle.$$
#
# We choose the spin convention
#
# $$n_i=\frac{1-\sigma_i^z}{2}.$$
#
# Consequently,
#
# $$|g\rangle\longleftrightarrow\sigma_i^z=+1,\qquad |r\rangle\longleftrightarrow\sigma_i^z=-1.$$
#
# ### 2.1 Mapping the spin–spin interaction
#
# Insert
#
# $$n_i=\frac{1-\sigma_i^z}{2}$$
#
# into one Rydberg interaction term:
#
# $$u_{ij}n_i n_j=\frac{u_{ij}}{4}(1-\sigma_i^z)(1-\sigma_j^z).$$
#
# Expanding gives
#
# $$u_{ij}n_i n_j=\frac{u_{ij}}4\left(1-\sigma_i^z-\sigma_j^z+\sigma_i^z\sigma_j^z\right).$$
#
# This expression contains four contributions:
#
# $$\underbrace{\frac{u_{ij}}4}_{\text{constant}}-\underbrace{\frac{u_{ij}}4\sigma_i^z+\frac{u_{ij}}4\sigma_j^z}_{\text{single-site fields}}+\underbrace{\frac{u_{ij}}4\sigma_i^z\sigma_j^z}_{\text{Ising interaction}}.$$
#
# The constant shifts every energy equally and therefore does not affect the dynamics. The last term reproduces the material Ising interaction, so
#
# $$\boxed{J_{ij}=\frac{u_{ij}}4}.$$
#
# For nearest neighbours,
#
# $$\boxed{J_1=\frac{u_1}{4}},$$
#
# where $u_1$ is the nearest-neighbour Rydberg interaction.
#
# Because $u_{ij}>0$, we obtain $J_{ij}>0$: the effective Ising coupling is antiferromagnetic.
#
# ### 2.2 Mapping the transverse field
#
# The transverse parts of the two Hamiltonians are
#
# $$\Delta_x\sum_i\sigma_i^x$$
#
# and
#
# $$\frac{\Omega}{2}\sum_i\sigma_i^x.$$
#
# Matching their coefficients gives
#
# $$\boxed{\Delta_x=\frac{\Omega}{2}}.$$
#
# Using $J_1=u_1/4$,
#
# $$\frac{\Delta_x}{J_1}=\frac{\Omega/2}{u_1/4}=\frac{2\Omega}{u_1}.$$
#
# The material value is approximately
#
# $$\frac{\Delta_x}{J_1}=1.08.$$
#
# Therefore, the required neutral-atom ratio is
#
# $$1.08=\frac{2\Omega}{u_1},$$
#
# or
#
# $$\boxed{\frac{\Omega}{u_1}=0.54}.$$
#
# Thus, once $u_1$ is fixed by the lattice spacing, the required maximum Rabi frequency is
#
# $$\Omega=0.54u_1.$$
#
# ### 2.3 Why the longitudinal-field mapping contains an offset
#
# The detuning term becomes
#
# $$-\delta n_i=-\frac{\delta}{2}+\frac{\delta}{2}\sigma_i^z.$$
#
# Again, the first term is an irrelevant constant. The second term acts as a single-site longitudinal field.
#
# However, the expansion of $u_{ij}n_i n_j$ also generated single-site terms. Collecting all interaction contributions acting on site $i$ gives
#
# $$-\frac14\sum_{j\neq i}u_{ij}\sigma_i^z.$$
#
# Combining this with the detuning contribution gives
#
# $$\left(\frac{\delta}{2}-\frac14\sum_{j\neq i}u_{ij}\right)\sigma_i^z.$$
#
# The material Hamiltonian writes its longitudinal term as
#
# $$-\Delta_{z,i}\sigma_i^z.$$
#
# Therefore,
#
# $$\Delta_{z,i}=\frac14\sum_{j\neq i}u_{ij}-\frac{\delta}{2}.$$
#
# Define the local interaction-induced detuning offset
#
# $$\boxed{\delta_{U,i}=\frac12\sum_{j\neq i}u_{ij}}.$$
#
# Then the local effective longitudinal field is
#
# $$\boxed{\Delta_{z,i}=\frac{\delta_{U,i}-\delta}{2}}.$$
#
# This equation is important: the material field is not determined by the laser detuning alone. It is shifted by the interactions with all other atoms.
#
# ### 2.4 Replacing the local offset with one global value
#
# Pulser programs one global detuning $\delta$, but an open array does not have the same interaction environment at every site:
#
# - central atoms have more surrounding neighbours;
# - edge and corner atoms have fewer neighbours.
#
# Therefore,
#
# $$\delta_{U,i}$$
#
# is site-dependent.
#
# To define one global control mapping, we average over all $N$ atoms:
#
# $$\delta_U=\frac1N\sum_i\delta_{U,i}.$$
#
# Using the definition of $\delta_{U,i}$,
#
# $$\delta_U=\frac1{2N}\sum_i\sum_{j\neq i}u_{ij}.$$
#
# The double sum counts every pair twice, so this is equivalent to
#
# $$\boxed{\delta_U=\frac1N\sum_{i<j}u_{ij}}.$$
#
# The array-averaged material field is then
#
# $$\boxed{\Delta_z=\frac{\delta_U-\delta}{2}}.$$
#
# Dividing by $J_1=u_1/4$ gives the dimensionless field scanned in the paper:
#
# $$\frac{\Delta_z}{J_1}=\frac{(\delta_U-\delta)/2}{u_1/4}.$$
#
# Therefore,
#
# $$\boxed{\frac{\Delta_z}{J_1}=\frac{2(\delta_U-\delta)}{u_1}}.$$
#
# ### 2.5 Inverse map: material field to programmed detuning
#
# For every desired material field
#
# $$h=\frac{\Delta_z}{J_1},$$
#
# we solve the previous equation for the required final detuning:
#
# $$h=\frac{2(\delta_U-\delta_{\mathrm{target}})}{u_1}.$$
#
# This gives
#
# $$\boxed{\delta_{\mathrm{target}}=\delta_U-\frac{h\,u_1}{2}}.$$
#
# Equivalently,
#
# $$\boxed{\delta_{\mathrm{target}}=\delta_U-\frac12\left(\frac{\Delta_z}{J_1}\right)u_1}.$$
#
# Increasing the desired material field therefore lowers the programmed detuning:
#
# $$\frac{\Delta_z}{J_1}\uparrow\quad\Longrightarrow\quad\delta_{\mathrm{target}}\downarrow.$$
#
# With our spin convention, a larger positive $\Delta_z$ favours
#
# $$\sigma_i^z=+1\longleftrightarrow|g\rangle,$$
#
# so the high-field state contains fewer Rydberg excitations and its magnetisation approaches $M^z=+1$.
#
# ### 2.6 Final control dictionary
#
# $$\boxed{J_{ij}=\frac{u_{ij}}4}$$
#
# $$\boxed{\frac{\Delta_x}{J_1}=\frac{2\Omega}{u_1}}$$
#
# $$\boxed{\frac{\Delta_z}{J_1}=\frac{2(\delta_U-\delta)}{u_1}}$$
#
# Because the interaction offset remains site-dependent near open boundaries, the global mapping is only exact after averaging over the chosen array. The notebook evolves all 49 atoms but evaluates its observables on the central $5\times5$ region to reduce—although not eliminate—boundary effects.

# %% [markdown]
# ## 3. Construct the triangular register and interaction shells
#
# ### 3.1 Positioning the atoms
#
# A triangular lattice is generated by two vectors of equal length $a$ separated by $60^\circ$:
#
# $$\mathbf e_1=a(1,0),\qquad \mathbf e_2=a\left(\frac12,\frac{\sqrt3}{2}\right).$$
#
# Here $a$ is the nearest-neighbour spacing. The atom with integer lattice coordinates $(i,j)$ is placed at
#
# $$\boxed{\mathbf r_{ij}=i\mathbf e_1+j\mathbf e_2}.$$
#
# For example, $(1,0)$ and $(0,1)$ are both a distance $a$ from $(0,0)$. Using $i,j=0,\ldots,6$ creates the $7\times7=49$-atom rhombus used in this notebook.
#
# ### 3.2 Choosing the nearest-neighbour spacing
#
# The material mapping requires
#
# $$\frac{\Omega}{u_1}=0.54,$$
#
# where $u_1$ is the nearest-neighbour Rydberg interaction. We keep the paper-like value
#
# $$\frac{\Omega}{2\pi}=2~\mathrm{MHz},$$
#
# which fixes
#
# $$u_1=\frac{\Omega}{0.54},\qquad \frac{u_1}{2\pi}\approx3.704~\mathrm{MHz}.$$
#
# Rydberg atoms interact through the van der Waals law
#
# $$u(r)=\frac{C_6/\hbar}{r^6}.$$
#
# For nearest neighbours, $r=a$, so the required spacing satisfies
#
# $$u_1=\frac{C_6/\hbar}{a^6},\qquad a=\left(\frac{C_6/\hbar}{u_1}\right)^{1/6}.$$
#
# The notebook uses `MockDevice.rydberg_blockade_radius(u1)` to perform this interaction-to-distance conversion. Here the function is being used simply to find the distance at which the `MockDevice` interaction equals $u_1$.
#
# The resulting spacing is about $7.84~\mu\mathrm m$, whereas the paper uses approximately $9~\mu\mathrm m$. This difference occurs because `MockDevice` and the experimental Rydberg state have different $C_6$ coefficients. The physical geometry is therefore not identical, but the central dimensionless ratio remains correct:
#
# $$\frac{\Delta_x}{J_1}=\frac{2\Omega}{u_1}=1.08.$$
#
# ### 3.3 Interaction shells
#
# Pairs of atoms occurring at the same distance form an interaction shell. Because $u(r)\propto r^{-6}$, the interaction relative to the nearest-neighbour value is
#
# $$\boxed{\frac{u(r)}{u_1}=\left(\frac{a}{r}\right)^6}.$$
#
# The first shells of the triangular lattice are therefore
#
# $$r=a:\quad \frac{u}{u_1}=1,$$
#
# $$r=\sqrt3a:\quad \frac{u}{u_1}=\frac1{27}\approx0.037,$$
#
# $$r=2a:\quad \frac{u}{u_1}=\frac1{64}\approx0.0156,$$
#
# $$r=\sqrt7a:\quad \frac{u}{u_1}=\frac1{343}\approx0.00292.$$
#
# Since $J_{ij}=u_{ij}/4$, the same ratios hold for the effective Ising couplings. In particular, the second shell gives
#
# $$\frac{J_2}{J_1}=\frac1{27}\approx0.037,$$
#
# which is close to the material estimate $J_2/J_1\approx0.05$, although it cannot be tuned independently. EmuMPS retains all pairwise $1/r^6$ interactions, including the weaker shells; the simulation is not truncated to only $J_1$ and $J_2$. Thus the lattice positions determine both the triangular geometry and the complete hierarchy of interaction strengths.

# %%
omega=2*np.pi*OMEGA_OVER_2PI_MHZ
u1=omega/(TARGET_DX_OVER_J1/2)
spacing=MockDevice.rydberg_blockade_radius(u1)
e1=spacing*np.array([1.,0.]);e2=spacing*np.array([.5,np.sqrt(3)/2])
ij=np.array([(i,j) for i in range(L) for j in range(L)])
xy=np.array([i*e1+j*e2 for i,j in ij])
register=Register.from_coordinates(xy,prefix='q')
r=np.linalg.norm(xy[:,None,:]-xy[None,:,:],axis=-1)
u=np.zeros_like(r);mask=r>0;u[mask]=MockDevice.interaction_coeff/r[mask]**6
delta_u=np.triu(u,1).sum()/N
local_delta_u=.5*u.sum(axis=1)
pair_r=r[np.triu_indices(N,1)]/spacing;pair_u=u[np.triu_indices(N,1)]/u1
print(f'spacing={spacing:.3f} µm, u1/2π={u1/(2*np.pi):.3f} MHz')
print(f'Omega/u1={omega/u1:.3f}, Delta_x/J1={2*omega/u1:.3f}')
print(f'global delta_U/u1={delta_u/u1:.3f}')
for shell in [1.,np.sqrt(3),2.,np.sqrt(7)]:
    m=np.isclose(pair_r,shell,rtol=1e-5)
    print(f'r/a={shell:.6f}: U/U1={pair_u[m].mean():.6f}, pairs={m.sum()}')
assert np.isclose(2*omega/u1,1.08)
assert np.isclose(pair_u[np.isclose(pair_r,np.sqrt(3),rtol=1e-5)].mean(),1/27,rtol=1e-4)
# Out:
# spacing=7.844 µm, u1/2π=3.704 MHz
# Omega/u1=0.540, Delta_x/J1=1.080
# global delta_U/u1=2.565
# r/a=1.000000: U/U1=1.000000, pairs=120
# r/a=1.732051: U/U1=0.037037, pairs=96
# r/a=2.000000: U/U1=0.015625, pairs=95
# r/a=2.645751: U/U1=0.002915, pairs=148

# %% [markdown]
# ## 4. Full array versus measured bulk
#
# All 49 atoms are evolved and interact throughout the EmuMPS simulation. We calculate the reported observables only on sites with $1\le i,j\le5$, corresponding to the central $5\times5$ region. The remaining 24 grey atoms are not discarded from the physics: they form an active one-row outer buffer and continue to interact with the measured sites, helping reduce direct edge effects. The three colours identify the $A$, $B$, and $C$ sublattices of the 1/3 ordering pattern. Because 25 is not divisible by three, the central region contains 9, 8, and 8 sites from these sublattices; the complex-phase structure-factor formula naturally accounts for this finite-size imbalance. Using 25 measured sites improves sampling statistics, but it is a deliberate departure from the paper's stricter two-layer-buffer convention and therefore retains greater boundary sensitivity.

# %%
bulk_mask=(ij[:,0]>=1)&(ij[:,0]<=5)&(ij[:,1]>=1)&(ij[:,1]<=5)
bulk_indices=np.flatnonzero(bulk_mask);Nb=len(bulk_indices)
bulk_ij=ij[bulk_indices];bulk_colours=(bulk_ij[:,0]-bulk_ij[:,1])%3
all_colours=(ij[:,0]-ij[:,1])%3
assert Nb==25 and np.array_equal(np.sort(np.bincount(bulk_colours,minlength=3)),[8,8,9])
palette=np.array(['#1D9E75','#B4408B','#E69F00'])
fig,ax=plt.subplots(figsize=(7.2,6.2))
for i in range(N):
    for j in range(i+1,N):
        if np.isclose(r[i,j],spacing,rtol=1e-6): ax.plot(xy[[i,j],0],xy[[i,j],1],color='.86',lw=.8,zorder=0)
ax.scatter(xy[~bulk_mask,0],xy[~bulk_mask,1],s=85,color='.78',edgecolor='white',label='buffer',zorder=2)
for colour,label in enumerate('ABC'):
    m=bulk_mask&(all_colours==colour)
    ax.scatter(xy[m,0],xy[m,1],s=150,color=palette[colour],edgecolor='black',label=f'bulk {label}',zorder=3)
for index in bulk_indices: ax.text(*xy[index],str(index),ha='center',va='center',fontsize=8,color='white',fontweight='bold',zorder=4)
ax.set_aspect('equal');ax.set_xlabel(r'$x$ ($\mu$m)');ax.set_ylabel(r'$y$ ($\mu$m)')
ax.set_title(r'$7\times7$ array and central $5\times5$ measured region');ax.legend(bbox_to_anchor=(1.02,1));fig.tight_layout()
print('bulk indices',bulk_indices)
print('mean bulk delta_U/u1',local_delta_u[bulk_indices].mean()/u1,'| global',delta_u/u1)
# Out:
# bulk indices [ 8  9 10 11 12 15 16 17 18 19 22 23 24 25 26 29 30 31 32 33 36 37 38 39
#  40]
# mean bulk delta_U/u1 3.1469788884490235 | global 2.5651197360663702

# %% [markdown]
# ## 5. Paper-inspired pulse construction and visualisation
#
# A separate pulse prepares the system for every target material field $h=\Delta_z/J_1$. All pulses begin from
#
# $$\Omega(0)=0,\qquad \delta_i=-3u_1.$$
#
# At zero Rabi frequency, this negative detuning strongly favours the simple all-$|g\rangle$ initial state. The target field is converted into the final detuning using
#
# $$\delta_{\mathrm{target}}=\delta_U-\frac{h u_1}{2}.$$
#
# The supplementary material specifies a quasi-adiabatic preparation lasting approximately $5~\mu\mathrm{s}$, followed by an $\Omega$ switch-off as rapidly as possible, but it does not provide every waveform control point. We therefore use the following transparent reconstruction:
#
# | Stage | Time | Rabi frequency $\Omega(t)$ | Detuning $\delta(t)$ | Purpose |
# |---|---:|---|---|---|
# | 1. Turn on fluctuations | $0$–$1~\mu\mathrm{s}$ | $0\rightarrow0.54u_1$ | fixed at $\delta_i$ | Gradually activate quantum spin flips. |
# | 2. Sweep the material field | $1$–$5~\mu\mathrm{s}$ | fixed at $0.54u_1$ | $\delta_i\rightarrow\delta_{\mathrm{target}}$ | Move quasi-adiabatically toward the requested field. |
# | 3. Freeze for readout | $5$–$5.1~\mu\mathrm{s}$ | $0.54u_1\rightarrow0$ | fixed at $\delta_{\mathrm{target}}$ | Suppress further coherent spin flips before sampling. |
#
# During stage 2, the mapping
#
# $$h(t)=\frac{2[\delta_U-\delta(t)]}{u_1}$$
#
# means that a linear detuning ramp produces a linear material-field ramp in the opposite direction: increasing $\delta$ decreases $h$. The first two stages together form the $5~\mu\mathrm{s}$ preparation. The final 100-ns ramp approximates the AOM (sound-controlled laser modulator) timescale quoted in the supplement; the faster $\sim20$-ns FM1 EOM (electric-field-controlled laser modulator) switch-off could be tested separately as a robustness check.
#
# The plot below shows the pulse for the representative target $h=4$. Every scan point uses the same timing and maximum Rabi frequency; only $\delta_{\mathrm{target}}$ changes. This is a documented paper-inspired reconstruction, not the unpublished experimental waveform.

# %%
def material_to_detuning(field): return delta_u-.5*field*u1
def detuning_to_material(delta): return 2*(delta_u-delta)/u1
def build_sequence(field):
    di=-3*u1;df=material_to_detuning(field)
    seq=Sequence(register,MockDevice);seq.declare_channel('rydberg_global','rydberg_global')
    seq.add(Pulse(RampWaveform(1000,0,omega),ConstantWaveform(1000,di),0),'rydberg_global')
    seq.add(Pulse(ConstantWaveform(4000,omega),RampWaveform(4000,di,df),0),'rydberg_global')
    seq.add(Pulse(RampWaveform(100,omega,0),ConstantWaveform(100,df),0),'rydberg_global')
    return seq
test_fields=np.array([1.,4.,10.]);assert np.allclose([detuning_to_material(material_to_detuning(x)) for x in test_fields],test_fields)
representative=4.
initial_detuning=-3*u1
target_detuning=material_to_detuning(representative)
initial_field=detuning_to_material(initial_detuning)
print('Representative pulse: programmed controls and material-field interpretation')
print(f'  Start: detuning δ_i/u₁ = {initial_detuning/u1:.3f}  →  material field (Δ_z/J₁)_i = {initial_field:.3f}')
print(f'  End:   target field (Δ_z/J₁)_f = {representative:.3f}  →  detuning δ_f/u₁ = {target_detuning/u1:.3f}')
print(f'  Evolution: material field decreases from {initial_field:.3f} to {representative:.3f}.')
build_sequence(representative).draw()
# Out:
# Representative pulse: programmed controls and material-field interpretation
#   Start: detuning δ_i/u₁ = -3.000  →  material field (Δ_z/J₁)_i = 11.130
#   End:   target field (Δ_z/J₁)_f = 4.000  →  detuning δ_f/u₁ = 0.565
#   Evolution: material field decreases from 11.130 to 4.000.

# %% [markdown]
# ## 6. Fresh Pasqal EmuMPS submission with persistent IDs
#
# A full 49-qubit state has $2^{49}$ amplitudes, so we use a matrix product state (MPS). Bond dimension $\chi$ limits retained entanglement: larger $\chi$ is more expressive and more expensive. The main scan uses $\chi=50$; selected transition points use $100$. The numerical time step is $dt=10$ ns.
#
# Run the next cell with `SUBMIT_NEW_JOBS=True` exactly once. It refuses to overwrite an existing manifest.

# %%
SUBMIT_NEW_JOBS=False

def cloud_connection():
    c=yaml.safe_load(Path(CREDENTIALS_FILE).read_text())
    return PasqalCloud(username=c['username'],project_id=c['project_id'],password=c['password'])
def submit_one(connection,field,chi):
    cfg=pulser.backend.EmulationConfig(observables=(BitStrings(evaluation_times=[1.0],num_shots=SHOTS),),dt=DT_NS,max_bond_dim=chi)
    return pulser.backends.EmuMPSBackend(build_sequence(field),config=cfg,connection=connection).run().batch_id
if SUBMIT_NEW_JOBS:
    if BATCH_FILE.exists(): raise FileExistsError(f'{BATCH_FILE} exists; refusing duplicate submission.')
    connection=cloud_connection()
    batches={'metadata':{'L':L,'shots':SHOTS,'dt_ns':DT_NS,'chi_main':CHI_MAIN,'chi_check':CHI_CHECK},'chi50':{},'chi100':{}}
    for field in FIELDS:
        bid=submit_one(connection,float(field),CHI_MAIN);batches['chi50'][str(float(field))]=bid;print('chi50',field,bid)
    for field in CHECK_FIELDS:
        bid=submit_one(connection,float(field),CHI_CHECK);batches['chi100'][str(float(field))]=bid;print('chi100',field,bid)
    BATCH_FILE.write_text(json.dumps(batches,indent=2));print('saved',BATCH_FILE)
else:
    print('Submission disabled. Inspect first; set SUBMIT_NEW_JOBS=True once when ready.')
# Out:
# Submission disabled. Inspect first; set SUBMIT_NEW_JOBS=True once when ready.

# %% [markdown]
# ## 7. Retrieve completed jobs
#
# After submission, wait until the Pasqal dashboard shows `DONE`, set `SUBMIT_NEW_JOBS=False`, and run below. The status guard prevents incomplete jobs from becoming data.

# %%
if not BATCH_FILE.exists(): raise FileNotFoundError('Submit fresh jobs first.')
saved=json.loads(BATCH_FILE.read_text());cred=yaml.safe_load(Path(CREDENTIALS_FILE).read_text())
sdk=SDK(username=cred['username'],project_id=cred['project_id'],password=cred['password'])
def retrieve(group):
    out={}
    for field,bid in saved[group].items():
        batch=sdk.get_batch(bid);status=str(batch.status);print(group,field,status)
        if status!='DONE': raise RuntimeError(f'{bid} is {status}; wait and rerun.')
        result=batch.ordered_jobs[0].result
        if not isinstance(result,dict): raise TypeError(type(result))
        out[float(field)]=result
    return out
counts50=retrieve('chi50');counts100=retrieve('chi100')
# Out:
# chi50 1.0 DONE
# chi50 2.0 DONE
# chi50 2.5 DONE
# chi50 2.75 DONE
# chi50 3.0 DONE
# chi50 3.25 DONE
# chi50 3.5 DONE
# chi50 3.625 DONE
# chi50 3.75 DONE
# chi50 3.875 DONE
# chi50 4.0 DONE
# chi50 4.125 DONE
# chi50 4.25 DONE
# chi50 4.375 DONE
# chi50 4.5 DONE
# chi50 4.625 DONE
# chi50 4.875 DONE
# chi50 5.0 DONE
# chi50 5.125 DONE
# chi50 5.25 DONE
# chi50 5.375 DONE
# chi50 5.5 DONE
# chi50 5.625 DONE
# chi50 5.875 DONE
# chi50 6.0 DONE
# chi50 8.0 DONE
# chi50 10.0 DONE
# chi100 3.5 DONE
# chi100 4.0 DONE
# chi100 4.5 DONE
# chi100 5.0 DONE

# %% [markdown]
# ## 8. From EmuMPS bitstrings to the paper-aligned observables
#
# For every target field, EmuMPS returns many 49-bit measurement outcomes. Each bit is the measured Rydberg occupation of one atom:
#
# $$n_i=0\quad\text{for }|g\rangle,\qquad n_i=1\quad\text{for }|r\rangle.$$
#
# All 49 atoms participate in the simulation, but the observables below use only the $N_b=25$ bits belonging to the central $5\times5$ region.
#
# ### 8.1 Convert occupations into material spins
#
# The material spin variable takes values $z_i=\pm1$. We obtain it from each measured bit using
#
# $$\boxed{z_i=1-2n_i}.$$
#
# Therefore,
#
# $$n_i=0\Rightarrow z_i=+1,\qquad n_i=1\Rightarrow z_i=-1.$$
#
# In the lattice visualisations, these correspond respectively to a blue ground-state atom and a red Rydberg excitation.
#
# ### 8.2 Bulk magnetisation
#
# For one measurement shot $s$, the bulk magnetisation is the average of the 25 selected spins:
#
# $$M^{z,(s)}=\frac1{N_b}\sum_{i\in b}z_i^{(s)},\qquad N_b=25.$$
#
# Averaging over all sampled bitstrings gives the reported magnetisation:
#
# $$\boxed{M^z=\frac1{N_b}\sum_{i\in b}\langle z_i\rangle}.$$
#
# The brackets $\langle\cdot\rangle$ denote an average over measurement shots. Thus $M^z\approx+1$ means that most selected atoms are measured in $|g\rangle$, while $M^z\approx-1$ means that most are measured in $|r\rangle$.
#
# Magnetisation measures the overall spin polarisation, but it does not reveal how the spins are arranged in space. Two configurations can contain the same numbers of $+1$ and $-1$ spins while having very different ordering patterns. We therefore also calculate spatial correlations.
#
# ### 8.3 Connected correlations
#
# For a pair of sites, $z_i z_j=+1$ when the measured spins are equal and $z_i z_j=-1$ when they are opposite. Averaging this product over shots gives the ordinary correlation $\langle z_i z_j\rangle$.
#
# An ordinary correlation can be nonzero simply because both sites have a large average magnetisation. To remove this independent-background contribution, the paper uses the connected correlation
#
# $$\boxed{C_{ij}^{zz}=\langle z_i z_j\rangle-\langle z_i\rangle\langle z_j\rangle}.$$
#
# The subtracted term is what we would expect if the two sites behaved independently. Consequently, $C_{ij}^{zz}>0$ means that their fluctuations tend to agree, $C_{ij}^{zz}<0$ means that they tend to be opposite, and $C_{ij}^{zz}\approx0$ means that their joint behaviour is mostly explained by their separate averages. This subtraction prevents a nearly polarised state from appearing strongly ordered merely because most spins point in the same direction.
#
# ### 8.4 Select the three-sublattice ordering pattern
#
# The expected 1/3 phase divides the triangular lattice into three repeating sublattices $A$, $B$, and $C$. The paper detects this pattern at the ordering wavevector
#
# $$\mathbf q_{1/3}=\frac{2\pi}{3a}(1,\sqrt3).$$
#
# For a lattice position $\mathbf r_{ij}=i\mathbf e_1+j\mathbf e_2$,
#
# $$\mathbf q_{1/3}\cdot\mathbf r_{ij}=\frac{2\pi}{3}(i+2j).$$
#
# Because $i+2j$ and $i-j$ differ by $3j$, they are equivalent modulo three. We can therefore label each site by
#
# $$c_i=(i-j)\bmod3$$
#
# and assign it the complex phase
#
# $$\phi_i=e^{2\pi i c_i/3}.$$
#
# The three possible phases are separated by $120^\circ$:
#
# $$A:\;1,\qquad B:\;e^{2\pi i/3},\qquad C:\;e^{4\pi i/3}.$$
#
# These phases act as a spatial filter: correlations following the repeating $A$-$B$-$C$ pattern reinforce one another, while unrelated patterns tend to cancel. The actual phase of each of the 25 sites is used, so the calculation does not assume equal sublattice populations; the $9,8,8$ imbalance remains a finite-size effect.
#
# ### 8.5 Connected 1/3 structure factor
#
# The paper-aligned observable is
#
# $$\boxed{S^{zz}(\mathbf q_{1/3})=\frac1{N_b}\sum_{i,j\in b}\phi_i^*C_{ij}^{zz}\phi_j}.$$
#
# In compact matrix notation,
#
# $$\boxed{S^{zz}(\mathbf q_{1/3})=\frac1{N_b}\boldsymbol\phi^\dagger C^{zz}\boldsymbol\phi}.$$
#
# Here $C^{zz}$ is the $25\times25$ connected-correlation matrix and $\boldsymbol\phi$ contains the phase of every selected site. The matrix expression is simply a shorter form of the double sum over all $25^2=625$ site pairs. A larger value indicates that the connected correlations more strongly resemble the expected three-sublattice pattern.
#
# ### 8.6 Bootstrap uncertainty
#
# Both observables are estimated from a finite set of probabilistic bitstrings. Repeating the same finite-shot measurement would therefore produce slightly different values. To estimate this sampling uncertainty without submitting new EmuMPS jobs, we:
#
# 1. draw a new dataset of the same size from the existing shots **with replacement**;
# 2. recompute $M^z$ and the complete connected structure factor;
# 3. repeat this procedure 500 times;
# 4. use the 16th and 84th percentiles as an approximate 68% interval.
#
# These intervals appear later as vertical error bars. For $S^{zz}$, every bootstrap repetition recomputes $\langle z_i\rangle$, $\langle z_i z_j\rangle$, the full matrix $C^{zz}$, and the final structure factor. The bootstrap intervals quantify finite-shot sampling uncertainty only; they do not include finite-size, boundary, pulse, mapping, or MPS-truncation errors.

# %%
phase=np.exp(2j*np.pi*bulk_colours/3);rng=np.random.default_rng(20260711)
def expand(counts):
    rows=[]
    for b,m in counts.items():
        row=np.fromiter((int(x) for x in b),dtype=np.int8)
        if len(row)!=N: raise ValueError(len(row))
        rows.extend([row]*m)
    return np.asarray(rows,float)[:,bulk_indices]
def estimate(z,index):
    x=z[index];mean=x.mean(axis=0);C=x.T@x/len(x)-np.outer(mean,mean)
    return np.array([x.mean(),float(np.real(np.conjugate(phase)@C@phase)/Nb)])
def summarize(counts,nboot=500):
    z=1-2*expand(counts);center=estimate(z,np.arange(len(z)));boot=np.empty((nboot,2))
    for b in range(nboot): boot[b]=estimate(z,rng.integers(0,len(z),len(z)))
    lo,hi=np.quantile(boot,[.16,.84],axis=0);return {'center':center,'low':lo,'high':hi,'z':z}
# Known-answer checks.
ground='0'*N;g=summarize({ground:20},20);assert np.isclose(g['center'][0],1) and np.isclose(g['center'][1],0)
summary50={f:summarize(c) for f,c in sorted(counts50.items())};summary100={f:summarize(c) for f,c in sorted(counts100.items())}
for f,s in summary50.items(): print(f'{f:4.2f}  Mz={s["center"][0]:+.3f}  Szz={s["center"][1]:.3f}')
# Out:
# 1.00  Mz=+0.367  Szz=5.537
# 2.00  Mz=+0.472  Szz=2.895
# 2.50  Mz=+0.534  Szz=2.045
# 2.75  Mz=+0.548  Szz=2.048
# 3.00  Mz=+0.578  Szz=1.776
# 3.25  Mz=+0.596  Szz=1.533
# 3.50  Mz=+0.614  Szz=1.267
# 3.62  Mz=+0.621  Szz=1.303
# 3.75  Mz=+0.634  Szz=1.181
# 3.88  Mz=+0.653  Szz=1.123
# 4.00  Mz=+0.664  Szz=0.980
# 4.12  Mz=+0.673  Szz=0.910
# 4.25  Mz=+0.685  Szz=0.830
# 4.38  Mz=+0.699  Szz=0.754
# 4.50  Mz=+0.716  Szz=0.694
# 4.62  Mz=+0.733  Szz=0.671
# 4.88  Mz=+0.772  Szz=0.499
# 5.00  Mz=+0.794  Szz=0.479
# 5.12  Mz=+0.768  Szz=0.538
# 5.25  Mz=+0.761  Szz=0.599
# 5.38  Mz=+0.818  Szz=0.394
# 5.50  Mz=+0.846  Szz=0.325
# 5.62  Mz=+0.813  Szz=0.421
# 5.88  Mz=+0.883  Szz=0.246
# 6.00  Mz=+0.896  Szz=0.202
# 8.00  Mz=+0.985  Szz=0.032
# 10.00  Mz=+1.000  Szz=0.001

# %% [markdown]
# ## 9. Plot 1 — quantum-twin magnetisation
#
# Every vertical error bar is the 16th–84th percentile interval from bootstrap resampling the EmuMPS bitstrings (an approximate 68% finite-shot interval). It quantifies sampling uncertainty only. The $\chi=50$ circles form the main scan; the $\chi=100$ diamonds are convergence checks and receive their own independently bootstrapped error bars. The programmed field values are treated as exact, so no horizontal error bars are drawn.
#
# We also plot the variance of the magnetisation measured in individual shots. For shot $s$,
#
# $$M^{z,(s)}=\frac1{N_b}\sum_{i\in b}z_i^{(s)},$$
#
# and the physical shot-to-shot fluctuation is
#
# $$\boxed{\operatorname{Var}(M^z)=\langle(M^z)^2\rangle-\langle M^z\rangle^2}.$$
#
# A small variance means that repeated shots have similar magnetisations; a larger variance indicates stronger fluctuations and may highlight the crossover region. This variance is an observable calculated from the shot distribution, not the uncertainty of the mean magnetisation. Its error bars separately show the bootstrap uncertainty with which the variance itself is estimated.

# %%
fields=np.array(sorted(summary50));check=np.array(sorted(summary100))
mz=np.array([summary50[f]['center'][0] for f in fields])
mzerr=np.array([[summary50[f]['center'][0]-summary50[f]['low'][0] for f in fields],[summary50[f]['high'][0]-summary50[f]['center'][0] for f in fields]])
mz100=np.array([summary100[f]['center'][0] for f in check])
mzerr100=np.array([[summary100[f]['center'][0]-summary100[f]['low'][0] for f in check],[summary100[f]['high'][0]-summary100[f]['center'][0] for f in check]])
fig,ax=plt.subplots(figsize=(7,4.6))
ax.errorbar(fields,mz,yerr=mzerr,fmt='o-',capsize=4,capthick=1.4,elinewidth=1.4,label=r'$\chi=50$ (68% bootstrap)')
ax.errorbar(check,mz100,yerr=mzerr100,fmt='D',ms=7,capsize=4,capthick=1.4,elinewidth=1.4,label=r'$\chi=100$ (68% bootstrap)')
ax.set(xlabel=r'$\Delta_z/J_1$',ylabel=r'bulk $M^z$',title='Quantum-twin magnetisation');ax.grid(alpha=.25);ax.legend();fig.tight_layout()

# Variance of the per-shot bulk magnetisation, with bootstrap uncertainty.
variance_rng=np.random.default_rng(20260712)
def magnetisation_variance(summary,nboot=500):
    shot_m=summary['z'].mean(axis=1)
    center=float(np.var(shot_m,ddof=0))
    boot=np.empty(nboot)
    for b in range(nboot):
        sample=shot_m[variance_rng.integers(0,len(shot_m),len(shot_m))]
        boot[b]=np.var(sample,ddof=0)
    low,high=np.quantile(boot,[.16,.84])
    return center,float(low),float(high)

var50={f:magnetisation_variance(summary50[f]) for f in fields}
var100={f:magnetisation_variance(summary100[f]) for f in check}
mzvar=np.array([var50[f][0] for f in fields])
mzvarerr=np.array([[var50[f][0]-var50[f][1] for f in fields],
                    [var50[f][2]-var50[f][0] for f in fields]])
mzvar100=np.array([var100[f][0] for f in check])
mzvarerr100=np.array([[var100[f][0]-var100[f][1] for f in check],
                       [var100[f][2]-var100[f][0] for f in check]])
fig,ax=plt.subplots(figsize=(7,4.6))
ax.errorbar(fields,mzvar,yerr=mzvarerr,fmt='o-',capsize=4,capthick=1.4,elinewidth=1.4,label=r'$\chi=50$ (68% bootstrap)')
ax.errorbar(check,mzvar100,yerr=mzvarerr100,fmt='D',ms=7,capsize=4,capthick=1.4,elinewidth=1.4,label=r'$\chi=100$ (68% bootstrap)')
ax.set(xlabel=r'$\Delta_z/J_1$',ylabel=r'$\operatorname{Var}(M^z)$',title='Shot-to-shot bulk-magnetisation variance')
ax.grid(alpha=.25);ax.legend();fig.tight_layout()

# %% [markdown]
# ## 10. Plot 2 — connected 1/3 structure factor
#
# The connected structure factor is nonlinear because it subtracts $\langle z_i\rangle\langle z_j\rangle$. Each bootstrap replicate therefore resamples complete shots and recomputes the site means, correlation matrix, and structure factor together. The displayed 16th–84th percentile bars preserve correlations between atoms and again represent finite-shot uncertainty, not finite-size, pulse-calibration, or MPS-model error.

# %%
szz=np.array([summary50[f]['center'][1] for f in fields])
szzerr=np.array([[summary50[f]['center'][1]-summary50[f]['low'][1] for f in fields],[summary50[f]['high'][1]-summary50[f]['center'][1] for f in fields]])
szz100=np.array([summary100[f]['center'][1] for f in check])
szzerr100=np.array([[summary100[f]['center'][1]-summary100[f]['low'][1] for f in check],[summary100[f]['high'][1]-summary100[f]['center'][1] for f in check]])
fig,ax=plt.subplots(figsize=(7,4.6))
ax.errorbar(fields,szz,yerr=szzerr,fmt='o-',capsize=4,capthick=1.4,elinewidth=1.4,label=r'$\chi=50$ (68% bootstrap)')
ax.errorbar(check,szz100,yerr=szzerr100,fmt='D',ms=7,capsize=4,capthick=1.4,elinewidth=1.4,label=r'$\chi=100$ (68% bootstrap)')
ax.set(xlabel=r'$\Delta_z/J_1$',ylabel=r'$S^{zz}(\mathbf{q}_{1/3})$',title='Connected 1/3 structure factor');ax.grid(alpha=.25);ax.legend();fig.tight_layout()
print('max chi difference Mz',max(abs(summary100[f]['center'][0]-summary50[f]['center'][0]) for f in check))
print('max chi difference Szz',max(abs(summary100[f]['center'][1]-summary50[f]['center'][1]) for f in check))
# Out:
# max chi difference Mz 0.008959999999999968
# max chi difference Szz 0.0877384000000001

# %% [markdown]
# ## 11. Pseudo-critical crossover extraction
#
# ### What we are estimating
#
# A finite $7\times7$ system does not show a perfectly sharp thermodynamic phase transition. Its connected structure factor changes smoothly, so we estimate a **pseudo-critical crossover field**: the field at which a smooth fit to $S^{zz}(\mathbf q_{1/3})$ decreases most rapidly. This follows the paper's varying-window cubic-fit idea, adapted to our smaller $N=49$ system and central 25-site analysis region. The paper reports its structure-factor critical extraction only for $N=256$, where bulk behaviour is much stronger; our result must therefore not be presented as the thermodynamic critical point.
#
# ### Varying-window procedure
#
# We apply the extraction to the central values of the dense $\chi=50$ structure-factor scan. For every candidate field window, we:
#
# 1. select the simulated points inside the window;
# 2. fit a cubic polynomial $S_{\mathrm{fit}}(h)=ah^3+bh^2+ch+d$, with $h=\Delta_z/J_1$;
# 3. differentiate the cubic;
# 4. locate the most negative derivative, corresponding to the fastest decrease of our $S^{zz}(h)$ curve;
# 5. retain that field as one candidate crossover estimate.
#
# Rather than manually choosing favourable windows, both endpoints are varied systematically. Lower endpoints run from $2.5$ to $3.5$, upper endpoints from $4.25$ to $5.5$, and only comparable widths between $1.75$ and $2.5$ are retained. This produces 17 candidate windows under the current rule.
#
# ### Acceptance checks
#
# A fit is accepted only if it contains at least five simulated field points and its derivative minimum lies outside the outer 3% of the window. An extremum at a boundary is rejected because it suggests that the window does not surround the rapid-change region. The cell prints a complete audit containing each window, its number of points, its candidate field, and whether it was accepted. We require at least five accepted windows before reporting any estimate.
#
# For the current dense dataset, 9 of the 17 systematic windows pass these checks. Their mean gives the central $N=49$ crossover estimate, while their 16th and 84th percentiles form the shaded vertical band. This band measures **fit-window sensitivity**: it shows how much the extracted field changes when reasonable fitting intervals are varied.
#
# ### Three uncertainties that must not be confused
#
# - **Vertical point error bars:** 68% bootstrap intervals from finite bitstring sampling. They are displayed with the data but are not currently used as fit weights or propagated through the full crossover extraction.
# - **Shaded vertical band:** 16th–84th percentiles of the accepted window estimates. This measures fit-window sensitivity, not shot noise.
#
# The reported number is therefore an $N=49$, finite-time, finite-window pseudo-critical crossover estimate. Its window band is not a complete confidence interval and does not include finite-size, boundary, pulse, mapping, time-step, or MPS-truncation errors.

# %%
FIT_WINDOWS=[]
for lower in np.arange(2.5,3.51,.25):
    for upper in np.arange(4.25,5.51,.25):
        width=upper-lower
        if 1.75<=width<=2.5: FIT_WINDOWS.append((float(lower),float(upper)))

def one_window(x,y,lo,hi):
    m=(x>=lo)&(x<=hi);npoints=int(m.sum())
    if npoints<5:
        return {'accepted':False,'reason':'fewer than 5 points','window':(lo,hi),'npoints':npoints}
    coeff=np.polyfit(x[m],y[m],3);grid=np.linspace(lo,hi,2001)
    deriv=np.polyval(np.polyder(coeff),grid);xc=float(grid[np.argmin(deriv)])
    margin=.03*(hi-lo);at_boundary=xc<=lo+margin or xc>=hi-margin
    return {'accepted':not at_boundary,'reason':'boundary extremum' if at_boundary else 'accepted',
            'xc':xc,'coeff':coeff,'grid':grid,'fit':np.polyval(coeff,grid),
            'window':(lo,hi),'npoints':npoints}

fit_audit=[one_window(fields,szz,*w) for w in FIT_WINDOWS]
fits=[f for f in fit_audit if f['accepted']]
for f in fit_audit:
    estimate=f"xc={f['xc']:.3f}" if 'xc' in f else 'xc=undefined'
    print(f"window {f['window'][0]:.2f}–{f['window'][1]:.2f} | n={f['npoints']:2d} | {estimate} | {f['reason']}")
print(f'accepted {len(fits)} of {len(fit_audit)} systematically generated windows')

MIN_VALID_WINDOWS=5
if len(fits)<MIN_VALID_WINDOWS:
    print(f'Only {len(fits)} valid internal-slope fits; do not report a pseudo-critical estimate.')
else:
    estimates=np.array([f['xc'] for f in fits]);central=estimates.mean();lo,hi=np.quantile(estimates,[.16,.84])
    print(f'N=49 pseudo-critical crossover: {central:.3f} +{hi-central:.3f} -{central-lo:.3f} (fit-window sensitivity)')
    fig,ax=plt.subplots(figsize=(7,4.7));ax.errorbar(fields,szz,yerr=szzerr,fmt='o',capsize=4,capthick=1.4,elinewidth=1.4,label='EmuMPS (68% shot bootstrap)')
    for k,f in enumerate(fits):ax.plot(f['grid'],f['fit'],color='C1',alpha=.18,label='accepted cubic fits' if k==0 else None)
    ax.axvspan(lo,hi,color='black',alpha=.12,label=f'fit-window 16–84%: {lo:.2f}–{hi:.2f}')
    ax.axvline(central,ls='--',color='black',label=f'mean $h_c^{{(N=49)}}={central:.2f}$')
    ax.set(xlabel=r'$\Delta_z/J_1$',ylabel=r'$S^{zz}(\mathbf{q}_{1/3})$',title=r'$N=49$ pseudo-critical crossover from varying-window fits');ax.grid(alpha=.25);ax.legend(fontsize=8);fig.tight_layout()
# Out:
# window 2.50–4.25 | n=11 | xc=3.371 | accepted
# window 2.50–4.50 | n=13 | xc=3.410 | accepted
# window 2.50–4.75 | n=14 | xc=3.410 | accepted
# window 2.50–5.00 | n=16 | xc=3.334 | accepted
# window 2.75–4.50 | n=12 | xc=2.750 | boundary extremum
# window 2.75–4.75 | n=13 | xc=2.750 | boundary extremum
# window 2.75–5.00 | n=15 | xc=2.750 | boundary extremum
# window 2.75–5.25 | n=17 | xc=2.879 | accepted
# window 3.00–4.75 | n=12 | xc=3.000 | boundary extremum
# window 3.00–5.00 | n=14 | xc=3.000 | boundary extremum
# window 3.00–5.25 | n=16 | xc=3.511 | accepted
# window 3.00–5.50 | n=18 | xc=3.000 | boundary extremum
# window 3.25–5.00 | n=13 | xc=3.494 | accepted
# window 3.25–5.25 | n=15 | xc=3.892 | accepted
# window 3.25–5.50 | n=17 | xc=3.250 | boundary extremum
# window 3.50–5.25 | n=14 | xc=4.133 | accepted
# window 3.50–5.50 | n=16 | xc=3.500 | boundary extremum
# accepted 9 of 17 systematically generated windows
# ...

# %% [markdown]
# ## 13. Supplementary visualisation: shot-averaged occupation near the crossover
#
# EmuMPS returns a count dictionary for every simulated field. Each key is a 49-bit measurement configuration and its value is the number of times that configuration occurred. Instead of displaying individual random shots, we use all sampled bitstrings to calculate the mean Rydberg occupation of every site:
#
# $$\boxed{\langle n_i\rangle=\frac{\sum_b C_b\,n_i(b)}{\sum_b C_b}},$$
#
# where $C_b$ is the observed count of bitstring $b$ and $n_i(b)$ is bit $i$ in that configuration. This count-weighted average is the estimated probability of measuring atom $i$ in the Rydberg state.
#
# We use the varying-window crossover estimate from Section 11 and plot the available scan fields nearest to $h_c-\Delta h$, $h_c$, and $h_c+\Delta h$, with $h=\Delta_z/J_1$ and $\Delta h=0.75$. The supplementary plot therefore requires the crossover-extraction cell to be run first.
#
# Every panel displays all 49 simulated atoms at their actual triangular-lattice positions. Black outlines identify the central $5\times5$ region used for the reported observables, while the outer atoms remain visible as the active buffer. The colour scale has a direct probabilistic meaning:
#
# - $\langle n_i\rangle\approx0$: the atom is usually measured in the ground state $|g\rangle$;
# - $\langle n_i\rangle\approx1$: it is usually measured in the Rydberg state $|r\rangle$;
# - $\langle n_i\rangle\approx0.5$: ground and Rydberg outcomes occur with similar frequency.
#
# This figure summarises the spatial measurement probabilities and their evolution across the crossover region. It is a supplementary interpretation tool, not an additional method for extracting the crossover field, and it does not display quantum phases or coherences.

# %%
# Select three already-simulated fields around the fitted crossover estimate.
hc_visual=float(central)

delta_h_visual = 0.75
targets = np.array([hc_visual-delta_h_visual, hc_visual, hc_visual+delta_h_visual])
visual_fields = np.array([fields[np.argmin(np.abs(fields-t))] for t in targets])
# Preserve order and remove a duplicate if two targets map to the same available field.
visual_fields = np.array(list(dict.fromkeys(visual_fields)), dtype=float)
print(f'fitted crossover used for visualisation: h_c = {hc_visual:.3f}')
print('available fields selected:', visual_fields)

def validated_bitstrings(counts):
    bitstrings=np.array(list(counts), dtype=str)
    weights=np.array([counts[b] for b in bitstrings], dtype=float)
    if len(bitstrings)==0 or np.any(np.char.str_len(bitstrings)!=N):
        raise ValueError('Expected non-empty 49-bit EmuMPS results.')
    if np.any(weights<0) or weights.sum()<=0:
        raise ValueError('Bitstring counts must be non-negative with a positive total.')
    return bitstrings,weights/weights.sum()

# `validated_bitstrings` returns every distinct 49-bit outcome and its normalised count.
# These probabilities are used in the next cell to average over all available shots.

# Shot-averaged Rydberg occupation on every one of the 49 sites.
# For each field, convert the distinct bitstrings into a matrix with one column per atom.
# Multiplying the normalised count vector p by this matrix gives
# mean_n[i] = sum_b p(b) * n_i(b), the estimated Rydberg probability at site i.
fig,axes=plt.subplots(1,len(visual_fields),figsize=(4.3*len(visual_fields),4),squeeze=False)
last_scatter=None
for ax,field in zip(axes[0],visual_fields):
    strings,p=validated_bitstrings(counts50[field])
    bit_array=np.array([[int(x) for x in b] for b in strings],dtype=float)
    mean_n=p@bit_array
    # Draw nearest-neighbour bonds only as a guide to the triangular geometry.
    for i in range(N):
        for j in range(i+1,N):
            if np.isclose(r[i,j],spacing,rtol=1e-6):
                ax.plot(xy[[i,j],0],xy[[i,j],1],color='.88',lw=.45,zorder=0)
    # Thick black borders identify the central 5x5 region used for observables.
    edge=np.where(bulk_mask,'black','white');width=np.where(bulk_mask,1.8,.6)
    last_scatter=ax.scatter(xy[:,0],xy[:,1],c=mean_n,cmap='viridis',vmin=0,vmax=1,
                            s=78,edgecolors=edge,linewidths=width,zorder=2)
    ax.set_title(rf'$\Delta_z/J_1={field:g}$');ax.set_aspect('equal');ax.axis('off')
fig.colorbar(last_scatter,ax=axes.ravel().tolist(),label=r'mean occupation $\langle n_i\rangle$',shrink=.78)
fig.suptitle('Shot-averaged Rydberg occupation around the pseudo-critical crossover',y=.98)
# Colour interpretation: 0 = usually |g>, 1 = usually |r>, and 0.5 = comparable frequencies.
# Out:
# fitted crossover used for visualisation: h_c = 3.493
# available fields selected: [2.75 3.5  4.25]
# Text(0.5, 0.98, 'Shot-averaged Rydberg occupation around the pseudo-critical crossover')

# %% [markdown]
# ## 14. Conclusion
#
# This notebook constructs a paper-inspired neutral-atom quantum twin of $\mathrm{TmMgGaO}_4$. Every EmuMPS run begins in the simple high-field polarised state, where $z_i=+1$, $n_i=0$, and the atoms are predominantly in $|g\rangle$. The effective material field is then decreased quasi-adiabatically from $\Delta_z/J_1\approx11.13$ to one chosen target value before the Rabi frequency is rapidly switched off for measurement. Each target field is prepared in an independent simulation.
#
# The expected physical evolution is a crossover from a high-field polarised phase toward a frustrated three-sublattice state as $\Delta_z/J_1$ decreases. At high field, the magnetisation approaches $M^z=+1$. Although the ordinary correlations are then large because all spins point similarly, the **connected** correlations are small after subtracting the uniform mean, so $S^{zz}(\mathbf q_{1/3})$ is close to zero. At lower field, antiferromagnetic interactions become more important and favour an approximate two-up, one-down arrangement: two bonds on each triangle are satisfied while one remains frustrated. This produces the characteristic $1/3$ magnetisation and $A$-$B$-$C$ correlations selected by the ordering wavevector $\mathbf q_{1/3}$.
#
# The observables provide complementary information. $M^z$ measures the average polarisation, $\operatorname{Var}(M^z)$ measures physical shot-to-shot magnetisation fluctuations, and $S^{zz}(\mathbf q_{1/3})$ detects the spatial three-sublattice correlations that magnetisation alone cannot reveal. Bootstrap intervals quantify how precisely these quantities are estimated from a finite number of bitstrings, whereas the $\chi=50/100$ comparison separately tests sensitivity to MPS truncation.
#
# Systematic varying-window cubic fits locate an $N=49$ pseudo-critical crossover near the region where the connected structure factor changes most rapidly. The spread between accepted windows measures fit-window sensitivity. This result is not a thermodynamic critical point and should not be identified with the paper's $N=256$ estimate. The shot-averaged occupation maps provide a spatial interpretation of the final Rydberg probabilities, but symmetry-related ordered configurations can average to a nearly uniform local pattern; the connected structure factor remains the more reliable ordering diagnostic.
#
# The main limitations are the finite $7\times7$ open array, the one-layer buffer and central 25-site analysis region, the global interaction-offset approximation, the difference between `MockDevice` and the physical device parameters, the reconstructed finite-duration pulse, MPS bond-dimension and time-step approximations, finite-shot sampling, and fit-window sensitivity. Within these limits, the notebook demonstrates the complete quantum-twin workflow: map the material Hamiltonian to neutral-atom controls, prepare and emulate the field-dependent state, extract experimentally accessible observables from bitstrings, test numerical and statistical stability, and identify the finite-size crossover toward three-sublattice order.
